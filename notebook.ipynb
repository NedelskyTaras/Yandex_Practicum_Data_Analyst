# %% [markdown]
# <div style="background:#d4d6fa; color:#000; padding:10px">
#     <p><big><b> Комментарий тимлида: </b></big></p>
# Здравствуй, Тарас! Меня зовут Москвин Антон! Я буду использовать стандартную цветовую разметку комментариев:
# <div class="alert alert-success">
#         <strong>👍 Зелёным</strong> цветом я буду выделять удачные и элегантные решения, на которые можно опираться в будущих проектах.
#     </div>
#     <div class="alert alert-warning">
#         <strong>⚠️Желтым</strong> будет выделено то, что в следующий раз стоит сделать по-другому. Одно-два таких замечаний в проекте допустимы, но если их будет больше, то нужно будет внести изменения.
#     </div>
#     <div class="alert alert-danger">
#         <strong>⛔️Красным</strong> - то, что необходимо исправить, прежде чем я смогу принять твой проект.
#     </div>
# Пожалуйста, НЕ УДАЛЯЙ и НЕ ПЕРЕДВИГАЙ их.
#     <br>СЛЕДУЮЩИЙ этап должен выполняться В ЭТОМ же ноутбуке!
# </div>

# %% [markdown]
# # Сегментация пользователей по потреблению
#
# **Цель проекта:** Уменьшение оттока клиентов.
#
# **Задачи проекта:**
# 1. Провести исследовательский анализ данных.
# 2. Сегментация пользователей на основе данных о количестве потребляемых продуктов.
# 3. Формулировка и проверка гипотез:
#     1. Проверьте гипотезу различия дохода между теми клиентами, которые пользуются двумя продуктами банка, и теми, которые пользуются одним.
#     2. Формулировка и проверка статистической гипотезы относительно предоставленных данных.
# 4. Предложение продуктов, которые могли бы удержать клиентов сегмента.
#
# **Описание данных:**
#
# Датасет содержит данные о клиентах банка «Метанпром». Банк располагается в Ярославле и областных городах: Ростов Великий и Рыбинск.
#
# Колонки:
# - `userid` — идентификатор пользователя,
# - `score` — баллы кредитного скоринга,
# - `City` — город,
# - `Gender` — пол,
# - `Age` — возраст,
# - `Objects` — количество объектов в собственности,
# - `Balance` — баланс на счёте,
# - `Products` — количество продуктов, которыми пользуется клиент,
# - `CreditCard` — есть ли кредитная карта,
# - `Loyalty` — активный клиент,
# - `estimated_salary` — заработная плата клиента,
# - `Churn` — ушёл или нет.
#
# **Этапы проекта:**
# 1. Предварительный анализ данных
# 2. Исследовательский анализ данных
# 3. Сегментация пользователей
# 4. Статистическое исследование
# 5. Общий вывод и рекомендации

# %% [markdown]
# <div class='alert alert-success'> 👍
# Спасибо за описание задачи! Помни что основная цель аналитики это снизить отток, выделение сегментов нужно для формирования более релевантных предложений которые помогут удержать клиентов.

# %% [markdown]
# <div class='alert alert-success'> 👍
# У тебя получился отличный план, продолжай работу над проектом в соответствии с пунктами данного плана!

# %% [markdown]
# ## Предварительный анализ данных
#
# Загрузка библиотек. Подробное изучение данных, выявление ошибок, дубликатов, явных и неявных пропусков. Описание возможных причин возникновения обнаруженных проблем.

# %% [markdown]
# ## Предобработка данных
#
# Исправление найденных на предыдущем этапе ошибок. Анализ выбросов, категоризация данных по возрасту, исследование пропусков и их заполнение, если это целесообразно.

# %% [markdown]
# ## Исследовательский анализ данных
#
# Исследование распределения признаков по оттоку клиентов. Составление графиков, формирование матрицы корреляций.

# %% [markdown]
# ## Сегментация
#
# Распределение признаков по сегментам в разрезе по числу потребляемых продуктов. Составление графиков и их изучение.

# %% [markdown]
# ## Статистическое исследование
#
# Формулировка гипотез на основе исследованных данных, и их проверка.

# %% [markdown]
# ## Общий вывод и рекомендации
#
# Обобщение сделанных на предыдущих этапах выводов. Составление рекомендаций по уменьшению оттока клиентов, предложение продуктов для изучаемых сегментов.
